# %% [markdown]
# # COGS 108 - Data Checkpoint

# %% [markdown]
# ## Authors

# %% [markdown]
# - Camille Tran: Proposal Data section, Hypothesis, and Research Question
# - Seungho Yeom: Proposal Reasearch Question, Background and Prior work
# - Yuvraj Bhatia: Proposal Data section, Research Question
# - Minyoung Kim: Proposal Background and Prior work, Team expectations, Timeline proposal
# - Vanessa Pham: Proposal Ethics, Team expectations

# %% [markdown]
# ## Research Question

# %% [markdown]
# <!-- **How can expectation disconfirmation between San Diego Airbnb host descriptions and guest experiences be quantified from text and reviews?** -->
# **For San Diego Airbnb listings (September 2025 snapshot), how do listing-level factors — superhost status, nightly price, neighborhood, room type, number of amenities, and description language characteristics — impact expectation disconfirmation between host-written listing descriptions and guest-reported experiences, as measured by our computed Expectation Gap metric?**
#
#
# According to Oliver (1977), **disconfirmation** is defined as the extent to which a consumer's initial expectations about a product's performance are met. It operates on a continuum ranging from unfavorable to favorable. Specifically, negative disconfirmation occurs when a product performs worse than expected, confirmation happens when it performs exactly as expected, and positive disconfirmation occurs when it performs better than anticipated.<a name="cite_ref-1"></a>[<sup>1</sup>](#cite_note-1)
#
# For our project, we measure this disconfirmation using a metric called the **Expectation Gap**, defined as follows:
#
# > **Expectation Gap = VADER(description) − mean(VADER(reviews))**
#
# where VADER produces a compound sentiment score from −1 (most negative) to +1 (most positive). A gap near 0 indicates the description sentiment matched review sentiment (confirmation); a large positive gap (> 0) means the host oversold the listing (negative disconfirmation: description more positive than guest experience); a negative gap means the host undersold it (positive disconfirmation: guests were pleasantly surprised).
#
# To answer these, we compute expectation disconfirmation from host description text and guest review text using VADER sentiment analysis (formula above). Specifically:
#
# - Which listing features — superhost status, price, neighborhood, room type, number of amenities, and description language — best explain why some listings have a smaller Expectation Gap than others?
# - Which of these features are the strongest predictors of a smaller Expectation Gap (absolute gap closer to 0)?
# - How does the Expectation Gap relate to guest-reported outcomes such as overall review scores (`review_scores_rating`, `review_scores_accuracy`) and estimated booking frequency (`estimated_occupancy_l365d` expressed as an occupancy rate)?
#
# 1. <a name="cite_note-1"></a> [^](#cite_ref-1) Oliver, R. L. (1977). Effect of expectation and disconfirmation on postexposure product evaluations: An alternative interpretation. Journal of Applied Psychology, 62(4), 480–486. https://doi.org/10.1037/0021-9010.62.4.480

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# Online peer-to-peer (P2P) marketplaces rely heavily on trust between users, and platforms like Airbnb are no exception. Because guests cannot physically visit a property before booking, they depend largely on host-provided listing descriptions, photos, and amenities to form expectations about their stay. Expectation–confirmation theory (ECT), developed by Oliver and widely applied in hospitality contexts, models satisfaction as this comparison between prior expectations and perceived performance; negative disconfirmation (worse than expected) leads to dissatisfaction, while confirmation or positive disconfirmation leads to satisfaction.<a name="cite_ref-1"></a>[<sup>1</sup>](#cite_note-1) <a name="cite_ref-2"></a>[<sup>2</sup>](#cite_note-2) When guests' experiences deviate significantly from their expectations, the resulting expectation gap can lead to lower ratings, negative reviews, reduced future demand, and erosion of platform trust.<br><br>
# ​
# Text‑mining work on Airbnb reviews shows what guests actually care about. Cheng and Jin analyze a large corpus of Airbnb review comments using topic modeling and sentiment analysis, finding that experiences are dominated by location, amenities, and host interaction, with a strong overall positivity bias in reviews.<a name="cite_ref-3"></a>[<sup>3</sup>](#cite_note-3) Other work confirms that Airbnb reviews are overwhelmingly positive and that criticism is often muted, which makes star ratings alone a poor indicator of underlying problems.<a name="cite_ref-4"></a>[<sup>4</sup>](#cite_note-4)<br>
#
# Expectation disconfirmation has been explicitly studied in the Airbnb context: Zhang et al. show that mismatches between expectations and experience, and how consistent reviews are, meaningfully affect guest attitudes and intention to recommend listings.<a name="cite_ref-5"></a>[<sup>5</sup>](#cite_note-5) Most directly related to this project, Cavique et al. measure semantic alignment between Airbnb host descriptions and guest reviews using word embeddings and clustering. They introduce a concept coverage ratio (how many review “concepts” are also present in the description) and find that higher coverage is generally associated with more positive review sentiment.<a name="cite_ref-2"></a>[<sup>2</sup>](#cite_note-2)<br><br>
# ​
# Building on this work, the proposed project defines a new expectation gap score that combines global semantic similarity between descriptions and reviews with host–guest sentiment differences (capturing overpromising vs. underpromising). It then uses supervised models to predict this score from pre-booking information (descriptions, amenities, host and listing features). In a diverse tourism market like San Diego, where listings range from luxury beachfront villas in La Jolla to urban studios in Little Italy, the factors contributing to expectation gaps are multifaceted. By quantifying which listing characteristics predict smaller expectation gaps, this project aims to provide actionable insights for hosts to improve transparency and for platforms to better calibrate guest expectations.
#
# 1. <a name="cite_note-1"></a> [^](#cite_ref-1) Oliver, R. L. (1977). Effect of expectation and disconfirmation on postexposure product evaluations: An alternative interpretation. Journal of Applied Psychology, 62(4), 480–486. https://doi.org/10.1037/0021-9010.62.4.480
# 2. <a name="cite_note-2"></a> [^](#cite_ref-2) Mariana Cavique, Ricardo Ribeiro, Fernando Batista, Antónia Correia, From host's descriptions to guests' reviews: Semantic similarities, Annals of Tourism Research Empirical Insights, Volume 6, Issue 2, 2025, 100187, ISSN 2666-9579, https://doi.org/10.1016/j.annale.2025.100187.
# 3. <a name="cite_note-3"></a> [^](#cite_ref-3) Mingming Cheng, Xin Jin, What do Airbnb users care about? An analysis of online review comments, International Journal of Hospitality Management, Volume 76, Part A, 2019, Pages 58-70, ISSN 0278-4319, https://doi.org/10.1016/j.ijhm.2018.04.004.
# 4. <a name="cite_note-4"></a> [^](#cite_ref-4) Bridges, Judith and Camilla Vásquez. “If nearly all Airbnb reviews are positive, does that make them meaningless?” Current Issues in Tourism 21 (2018): 2057 - 2075, https://api.semanticscholar.org/CorpusID:157317396
# 5. <a name="cite_note-5"></a> [^](#cite_ref-5) Lu Zhang, Wei Wei, Nathaniel D. Line, Yusi Cheng, When positive reviews backfire: The effect of review dispersion and expectation disconfirmation on Airbnb guests’ experiences, International Journal of Hospitality Management,
# Volume 96, 2021, 102979, ISSN 0278-4319, https://doi.org/10.1016/j.ijhm.2021.102979.

# %% [markdown]
# ## Hypothesis

# %% [markdown]
# We predict that listings with superhost status, more amenities, and grounded description language will have a smaller Expectation Gap (absolute gap closer to 0). Listings with smaller gaps will also have higher estimated booking frequency, measured by `estimated_occupancy_l365d` converted to an occupancy rate (estimated nights booked in the last 365 days, expressed as a percentage of the year).
#
# - Superhosts (Superhost status) need to maintain ≥4.8 rating, ≥90% response rate, and ≥10 stays/year to keep their badge, so they're more likely to write honest descriptions.
# - More amenities (Amenity count) give hosts concrete things to describe rather than relying on vague hype, which helps set expectations that the listing can actually deliver on.
# - A "grounded" description is one whose VADER score does not exceed the listing's mean review VADER score by more than 0.2 units — descriptions above this threshold are considered overpromising

# %% [markdown]
# ## Data

# %% [markdown]
# Our data comes from [Inside Airbnb](http://insideairbnb.com/get-the-data/), which is an independent open project that scrapes publicly available Airbnb data for cities around the world. The data is free to download and no application or permission needed. We will be using **San Diego** data from **September 2025**.
#
# ### Dataset #1 — San Diego Airbnb Listings Dataset: `listings.csv.gz`
# <!-- **Dataset 1: `listings.csv.gz`** -->
#
# This is the main file. It has 13,162 San Diego listings with 79 columns. Below are the relevant columns we have selected:
#
# <!-- | Column | Description | Purpose |
# |---|---|---|
# | `description` | The host's written description of their place | We run VADER sentiment analysis on this to get the host-side sentiment score |
# | `host_is_superhost` | Superhost badge (t/f) | Predictor |
# | `price` | Nightly price (stored as a string with `$`, needs cleaning) | Predictor |
# | `neighbourhood_cleansed` | Neighborhood name | Predictor |
# | `room_type` | Entire home, private room, shared room, or hotel room | Predictor |
# | `amenities` | JSON list of amenities | We count these per listing and use the count as a predictor |
# | `review_scores_rating` | Overall guest rating (0–5) | Used to validate our gap metric |
# | `review_scores_accuracy` | Accuracy sub-score from guests | This is the closest existing metric to what our gap tries to capture |
# | `number_of_reviews` | Total review count | We use this to filter to only keep listings with 5+ reviews |
# | `reviews_per_month` | Avg reviews per month | Substitute for how often the listing gets booked | -->
# | Column | Description | Purpose |
# |---|---|---|
# | `description` | Host's written listing description (free text, avg ~412 chars, contains HTML we strip) | We run sentiment analysis on this for the host-side score of the expectation gap |
# | `name` | Listing title (e.g., "Cozy Pacific Beach Hideaway!") | Could supplement description for text analysis |
# | `neighborhood_overview` | Host's description of the neighborhood (~40% missing — optional field) | Additional host text |
# | `host_about` | Host's self-description (~48% missing — optional field) | Could analyze host writing style |
# | `host_is_superhost` | Superhost badge (t/f). Requires ≥4.8 rating, ≥90% response rate, ≥10 stays/yr | Key predictor — superhosts must maintain standards, may write more honest descriptions |
# | `host_since` | Registration date → we compute `host_tenure_years` (mean 7.9 yrs) | Host experience predictor |
# | `host_response_time` | "within an hour", "within a few hours", "within a day", "a few days or more" | Host engagement predictor |
# | `host_response_rate` | Percentage string (e.g., "95%") → we convert to 0.95 | Host engagement predictor |
# | `host_acceptance_rate` | Percentage string → float. How often host accepts booking requests | Host selectivity predictor |
# | `host_identity_verified` | Whether Airbnb verified the host's government ID (t/f) | Trust signal predictor |
# | `calculated_host_listings_count` | Number of listings this host has in San Diego (1–169). Inside Airbnb calculated, NOT Airbnb's opaque global count | Casual host (1-2) vs professional operator (10+) predictor |
# | `neighbourhood_cleansed` | Neighborhood name (101 neighborhoods, geocoded from coordinates) | Predictor. Top: Mission Bay, Pacific Beach, La Jolla |
# | `property_type` | Host-selected building type (47 unique: "Entire home", "Entire condo", "Tiny home", etc.) | Needs grouping to ~4-6 categories for regression; see property_type vs room_type notes above |
# | `room_type` | Entire home/apt (88%), Private room (12%), Shared room, Hotel room | Predictor — what access level the guest gets |
# | `accommodates`, `bedrooms`, `beds` | Listing capacity and size (integers) | Listing size predictors |
# | `bathrooms_text` | Text like "2 baths", "1 private bath", "Half-bath" (39 unique values) → we parse to `bathrooms` (count) and `bath_type` (private/shared/unspecified) | Size predictor + private vs shared distinction could affect expectations |
# | `amenities` | JSON list of amenities → we extract `amenity_count` (mean ~44) | More amenities = more concrete things to describe rather than vague hype |
# | `price` | Nightly price in USD (stored as "$175.00", needs cleaning). Median $175, mean $281, right-skewed with outliers up to $50k | Predictor — higher price may set higher expectations |
# | `instant_bookable` | Whether guests can book without host approval (t/f) | Commercial/professional operation indicator |
# | `number_of_reviews` | All-time total review count | Used to filter: we require ≥5 reviews per listing |
# | `reviews_per_month` | Avg reviews/month over listing lifetime. Derived: `number_of_reviews / months_since_first_review` | Booking frequency proxy (normalized by listing age) |
# | `estimated_occupancy_l365d` | Estimated booked nights last year (0–255). Derived: `reviews_last_year × 2 × avg_stay_length`, capped at 70%. See formula in section above | Better booking frequency proxy for current demand |
# | `review_scores_rating` | Overall guest rating (0–5 scale) | Used to validate our computed gap |
# | `review_scores_accuracy` | Accuracy sub-score from guests (0–5) — "Was the listing accurate as described?" | Closest existing metric to our expectation gap — use for cross-validation |
# | `review_scores_cleanliness`, `_checkin`, `_communication`, `_location`, `_value` | Other guest sub-scores (all 0–5) | Subcategory validation |
#
# **Dataset concerns and shortcomings:**
#
# There are some concerns associated with this dataset based on the disclaimers and data assumptons provided by the scraping website.
#
# - **Single snapshot:**
# The dataset is composed of listings that were available at the time of scraping, which was done September 25, 2025. This means this dataset does not capture any listings deleted before or after this period. As a result, the sample may not fully represent the dynamic nature of the Airbnb market, and ay conclusions drawn apply only to listings active on September 25, 2025.
#
# - **No actual booking data:** Airbnb does not publish booking counts. Both `reviews_per_month` and `estimated_occupancy_l365d` are derived from review counts, not direct booking records. Standard in Airbnb research but are approximations.
#
# - **Availability ≠ bookings:**
# The Airbnb calendar for a listing does not differentiate between a booked night VS an unavailable night. All of these nights have been grouped into "unavailable". This introduces measurement bias, as highly popular listings are more likely to appear unavailable dure to bookings rather than host restrictions. Consequently, the data may systematically understate availability for successful listings and could misrepresent listing popularity if availability is used as a substitute for demand. This is why we are using occupancy estimates instead.
#
# - **Neighborhood geocoding:**
# Neighbourhood names for each listing are compiled by comparing the listing's geographic coordinates with a city's definition of neighbourhoods. Listings located near neighborhood borders may be misclassified if small coordinate errors or boundary discrepancies exist. Also, official neighborhood boundaries may not reflect how guests or hosts socially perceive or describe an area. Airbnb also anonymizes coordinates by 0~450 feet (150m).
#
# - **Price outliers:**
# After exploring the data, we found out that out of all the San Diego Airbnb listings, 28 of the listings cost over $2000 a night, up to the $50k range. We did flag it out as an outlier, but kept for sensitivity analysis.
#
#
# - **Description truncation:**
# It looks like the descriptions are capped at ~1,000 characters in our scraped data. This means any description exceeding 1,000 characters can not be reflected in our analysis.

# %%
#Imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import json
import re

# %%
# Run this code every time when you're actively developing modules in .py files.  It's not needed if you aren't making modules
#
## this code is necessary for making sure that any modules we load are updated here 
## when their source code .py files are modified

# %load_ext autoreload
# %autoreload 2

# %%
# Setup code -- this only needs to be run once after cloning the repo!
# this code downloads the data from its source to the `data/00-raw/` directory
# if the data hasn't updated you don't need to do this again!

# if you don't already have these packages (you should!) uncomment this line
# %pip install requests tqdm

import sys
sys.path.append('./modules') # this tells python where to look for modules to import

import get_data # this is where we get the function we need to download data

# replace the urls and filenames in this list with your actual datafiles
# yes you can use Google drive share links or whatever
# format is a list of dictionaries; 
# each dict has keys of 
#   'url' where the resource is located
#   'filename' for the local filename where it will be stored 
datafiles = [
    { 'url': 'https://data.insideairbnb.com/united-states/ca/san-diego/2025-09-25/data/listings.csv.gz', 'filename':'listings.csv.gz'},
    { 'url': 'https://data.insideairbnb.com/united-states/ca/san-diego/2025-09-25/data/reviews.csv.gz', 'filename':'reviews.csv.gz'}
]
## NOTE FROM CAMILLE: I RAN THIS CELL ALREADY, SO I COMMENTED OUT THE LINE BELOW TO AVOID RE-DOWNLOADING THE DATA.  
#Data files are already in the `data/00-raw/` directory, so you can skip this step if we don't need to update the data.
#YOU CAN UNCOMMENT IT IF YOU WANT TO DOWNLOAD THE DATA AGAIN.

#get_data.get_raw(datafiles,destination_directory='data/00-raw/')

# %% [markdown]
# ### San Diego Airbnb Listings Dataset: Load, Select Columns, Tidiness, Missingness

# %%
# Dataset 1 : Load, Select Columns, Tidiness, Missingness

# 1. load the raw dataset & 3. size of the dataset
listings_raw = pd.read_csv('data/00-raw/listings.csv.gz', compression='gzip')
print(f'Raw listings: {listings_raw.shape[0]:,} rows, {listings_raw.shape[1]} columns')

# 2. Select columns grouped by role in the project
keep_cols = [
    # identifiers & text
    'id', 'name', 'description', 'neighborhood_overview', 'host_about',
    # host characteristics (predictors)
    'host_is_superhost', 'host_since', 'host_response_time',
    'host_response_rate', 'host_acceptance_rate',
    'host_identity_verified',
    'calculated_host_listings_count',
    # listing characteristics (predictors)
    'neighbourhood_cleansed', 'property_type', 'room_type',
    'accommodates', 'bedrooms', 'beds', 'bathrooms_text',
    'amenities', 'price', 'instant_bookable',
    # outcomes & validation
    'number_of_reviews', 'reviews_per_month',
    'estimated_occupancy_l365d',
    'review_scores_rating', 'review_scores_accuracy',
    'review_scores_cleanliness', 'review_scores_checkin',
    'review_scores_communication', 'review_scores_location',
    'review_scores_value',
]
listings = listings_raw[keep_cols].copy()
print(f'Selected {len(keep_cols)} columns, {len(listings):,} rows')

# 3. Tidiness check — each row = one listing, each column = one variable 
#    Several columns need type conversion (price is string, booleans are t/f, etc.)
print('\nDtypes before cleaning:')
print(listings.dtypes.to_string())

# 4. Missing data: how much and where
print('\n'+ 50*'-')
print('MISSING DATA ASSESSMENT')
print(50*'-')
missing = listings.isnull().sum()
missing_pct = (missing / len(listings) * 100).round(1)
missing_df = pd.DataFrame({'missing_count': missing, 'missing_pct': missing_pct})
print(missing_df.sort_values('missing_pct', ascending=False).to_string())
print(f'\nTotal rows: {len(listings):,}')

# Is missingness systematic?
# Review scores + reviews_per_month are missing for the SAME 2,200 listings with 0 reviews
has_scores = listings['review_scores_rating'].notna()
print('\nReview count for listings WITH scores:')
print(listings.loc[has_scores, 'number_of_reviews'].describe().round(1))
print('\nReview count for listings WITHOUT scores:')
print(listings.loc[~has_scores, 'number_of_reviews'].describe().round(1))

# Visualize missingness
fig, ax = plt.subplots(figsize=(12, 6))
sns.heatmap(listings.isnull().T, cbar=False, yticklabels=True, cmap='viridis', ax=ax)
ax.set_title('Missing Data Heatmap (yellow = missing)')
ax.set_xlabel('Listing index')
plt.tight_layout()
plt.show()
# Out:
# Raw listings: 13,162 rows, 79 columns
# Selected 32 columns, 13,162 rows
#
# Dtypes before cleaning:
# id                                  int64
# name                               object
# description                        object
# neighborhood_overview              object
# host_about                         object
# host_is_superhost                  object
# host_since                         object
# host_response_time                 object
# host_response_rate                 object
# host_acceptance_rate               object
# host_identity_verified             object
# calculated_host_listings_count      int64
# neighbourhood_cleansed             object
# property_type                      object
# room_type                          object
# accommodates                        int64
# bedrooms                          float64
# beds                              float64
# bathrooms_text                     object
# amenities                          object
# ...

# %% [markdown]
# #### Is missingness systematic?
# - Missingness is NOT random...these are new/inactive listings with 0 reviews.
# - We will later filter for listings with 5+ reviews, which will remove all of them.

# %% [markdown]
# ### San Diego Airbnb Listings Dataset: Data Cleaning, Filtering, Outlier Detection

# %%
# Data set 1: Data Cleaning, Filtering, Outlier Detection

# ---- Clean price: '$175.00' → 175.0 ----
listings['price'] = (
    listings['price']
    .str.replace('$', '', regex=False)
    .str.replace(',', '', regex=False)
    .astype(float)
)
print('Price after cleaning:')
print(listings['price'].describe().round(2))

# ---- Clean boolean columns: 't'/'f' → True/False ----
for col in ['host_is_superhost', 'host_identity_verified', 'instant_bookable']:
    listings[col] = listings[col].map({'t': True, 'f': False})
print(f'\nBoolean columns cleaned: host_is_superhost, host_identity_verified, instant_bookable')

# ---- Clean host_response_rate and host_acceptance_rate: '95%' → 0.95 ----
for col in ['host_response_rate', 'host_acceptance_rate']:
    listings[col] = (
        listings[col]
        .str.replace('%', '', regex=False)
        .astype(float) / 100
    )
print(f'Percentage columns cleaned: host_response_rate (mean={listings["host_response_rate"].mean():.3f}), '
      f'host_acceptance_rate (mean={listings["host_acceptance_rate"].mean():.3f})')

# ---- Parse bathrooms_text ----
# Extracts TWO things:
#   bathrooms  — numeric count (e.g., 2.5; "Half-bath" → 0.5)
#   bath_type  — 'private', 'shared', or 'unspecified' (host didn't say either way)
def parse_bathrooms(text):
    if pd.isna(text):
        return np.nan
    text_lower = text.lower()
    if 'half-bath' in text_lower or 'half bath' in text_lower:
        return 0.5
    match = re.search(r'(\d+\.?\d*)', text)
    return float(match.group(1)) if match else np.nan

def parse_bath_type(text):
    # 'unspecified' means text just says e.g. '2 baths' — for entire homes
    #this is likely private, but the host didn't explicitly say.
    if pd.isna(text):
        return np.nan
    text_lower = text.lower()
    if 'private' in text_lower:
        return 'private'
    elif 'shared' in text_lower:
        return 'shared'
    return 'unspecified'

listings['bathrooms'] = listings['bathrooms_text'].apply(parse_bathrooms)
listings['bath_type'] = listings['bathrooms_text'].apply(parse_bath_type)
print(f'\nBathrooms parsed — bath_type distribution:')
print(listings['bath_type'].value_counts(dropna=False).to_string())

# ---- Parse host_since → host_tenure_years ----
listings['host_since'] = pd.to_datetime(listings['host_since'])
scrape_date = pd.Timestamp('2025-09-25')
listings['host_tenure_years'] = ((scrape_date - listings['host_since']).dt.days / 365.25).round(1)
print(f'\nHost tenure: mean={listings["host_tenure_years"].mean():.1f} yrs, '
      f'median={listings["host_tenure_years"].median():.1f} yrs')

# ---- Extract amenity count from JSON list ----
def count_amenities(amenity_str):
    if pd.isna(amenity_str):
        return 0
    try:
        return len(json.loads(amenity_str))
    except (json.JSONDecodeError, TypeError):
        return amenity_str.count(',') + 1

listings['amenity_count'] = listings['amenities'].apply(count_amenities)
print(f'Amenity count: mean={listings["amenity_count"].mean():.1f}, '
      f'median={listings["amenity_count"].median():.0f}')

# ---- Strip HTML from description, compute length ----
listings['description_clean'] = (
    listings['description']
    .fillna('')
    .str.replace(r'<br\s*/?>', ' ', regex=True)
    .str.replace(r'<[^>]+>', '', regex=True)
    .str.strip()
)
listings['desc_length'] = listings['description_clean'].str.len()
print(f'Description length (HTML stripped): mean={listings["desc_length"].mean():.0f} chars, '
      f'median={listings["desc_length"].median():.0f} chars')

# ---- Filter: must have description (≥10 chars) AND ≥5 reviews ----
print('\n'+ 50*'-')
print('FILTERING')
print(50*'-')
no_desc = listings['description_clean'].str.len() < 10
few_reviews = listings['number_of_reviews'] < 5
print(f'Total listings:             {len(listings):,}')
print(f'No/short description:       {no_desc.sum():,} ({no_desc.mean():.1%})')
print(f'Fewer than 5 reviews:       {few_reviews.sum():,} ({few_reviews.mean():.1%})')
listings_clean = listings[~no_desc & ~few_reviews].copy()
print(f'After filter:               {len(listings_clean):,}')

# Drop rows still missing price or superhost (can't use as predictors)
# host_response_time/rate, bedrooms, beds, bathrooms NaN → keep (handle in modeling)
before = len(listings_clean)
listings_clean = listings_clean.dropna(subset=['price', 'host_is_superhost'])
print(f'Dropped {before - len(listings_clean)} rows missing price or superhost → {len(listings_clean):,} remaining')

# ---- Outlier detection: price ----
print('\n'+ 50*'-')
print('OUTLIER DETECTION')
print(50*'-')
for t in [1000, 2000, 5000, 10000]:
    print(f'  Price > ${t:,}/night: {(listings_clean["price"] > t).sum()} listings')
listings_clean['price_outlier'] = listings_clean['price'] > 2000
print(f'Flagged as price outlier (>$2k): {listings_clean["price_outlier"].sum()} (kept in data for sensitivity analysis)')

# Outlier visualizations
fig, axes = plt.subplots(1, 3, figsize=(15, 4))
axes[0].hist(listings_clean['price'].clip(upper=1500), bins=50, edgecolor='black', alpha=0.7)
axes[0].set_title('Price Distribution (capped at $1,500)')
axes[0].set_xlabel('Price ($/night)')
axes[0].set_ylabel('Count')
axes[1].hist(listings_clean['amenity_count'], bins=40, edgecolor='black', alpha=0.7)
axes[1].set_title('Amenity Count Distribution')
axes[1].set_xlabel('Number of amenities')
axes[2].hist(listings_clean['estimated_occupancy_l365d'], bins=40, edgecolor='black', alpha=0.7)
axes[2].set_title('Estimated Occupancy (last 365 days)')
axes[2].set_xlabel('Nights booked')
plt.tight_layout()
plt.show()
# Out:
# Price after cleaning:
# count    11381.00
# mean       650.38
# std       4131.34
# min         11.00
# 25%        115.00
# 50%        176.00
# 75%        300.00
# max      50040.00
# Name: price, dtype: float64
#
# Boolean columns cleaned: host_is_superhost, host_identity_verified, instant_bookable
# Percentage columns cleaned: host_response_rate (mean=0.971), host_acceptance_rate (mean=0.900)
#
# Bathrooms parsed — bath_type distribution:
# bath_type
# unspecified    11316
# private         1027
# shared           726
# NaN               93
#
# Host tenure: mean=7.9 yrs, median=8.7 yrs
# Amenity count: mean=43.9, median=45
# Description length (HTML stripped): mean=391 chars, median=449 chars
#
# --------------------------------------------------
# FILTERING
# --------------------------------------------------
# Total listings:             13,162
# No/short description:       163 (1.2%)
# Fewer than 5 reviews:       4,009 (30.5%)
# After filter:               9,091
# ...

# %%
# ---- Remaining missingness after cleaning ----
print('\n'+ 50*'-')
print('REMAINING MISSINGNESS (after filtering & dropping)')
print(50*'-')
missing_clean = listings_clean.isnull().sum()
missing_clean_pct = (missing_clean / len(listings_clean) * 100).round(1)
missing_clean_df = pd.DataFrame({'missing': missing_clean, 'pct': missing_clean_pct})
remaining = missing_clean_df[missing_clean_df['missing'] > 0].sort_values('pct', ascending=False)
print(remaining.to_string())
# Out:
# --------------------------------------------------
# REMAINING MISSINGNESS (after filtering & dropping)
# --------------------------------------------------
#                        missing   pct
# neighborhood_overview     2594  32.9
# host_about                2466  31.3
# host_response_time         417   5.3
# host_response_rate         417   5.3
# host_acceptance_rate       321   4.1
# bedrooms                     4   0.1
# beds                         9   0.1

# %% [markdown]
# Notes for keeping these NaNs:
# - neighborhood_overview, host_about: optional text fields, not all hosts fill these in. We can use them for supplementary text analysis where available.
# - beds, bedrooms, bathrooms: small % missing (~1-10%), can fill with median by room_type during modeling.
#  - host_response_time/rate: missing when host hasn\'t received enough messages. Missingness itself is informative (less active host). Can encode as a separate category.
# - host_acceptance_rate: missing when host hasn\'t received enough booking requests.
# - bath_type: only 1 missing — negligible.

# %% [markdown]
# ### San Diego Airbnb Listings Dataset: Summary Statistics & Save

# %%
#Dataset 1: Summary Statistics & Save

print(f'\n--- Final Listings Dataset ---')
print(f'Observations: {len(listings_clean):,}')

print(f'\n--- Superhost ---')
print(listings_clean['host_is_superhost'].value_counts())

print(f'\n--- Room Type ---')
print(listings_clean['room_type'].value_counts())

print(f'\n--- Top 10 Neighborhoods ---')
print(listings_clean['neighbourhood_cleansed'].value_counts().head(10))

print(f'\n--- Key Numeric Variables ---')
summary_cols = ['price', 'amenity_count', 'accommodates', 'bedrooms', 'beds',
                'bathrooms', 'host_tenure_years', 'calculated_host_listings_count',
                'estimated_occupancy_l365d', 'reviews_per_month',
                'review_scores_rating', 'review_scores_accuracy', 'desc_length']
print(listings_clean[summary_cols].describe().round(2).to_string())

# Save processed listings
drop_cols = ['amenities', 'bathrooms_text', 'host_since', 'description']
listings_out = listings_clean.drop(columns=drop_cols)
listings_out = listings_out.rename(columns={'description_clean': 'description'})
listings_out.to_csv('data/02-processed/listings_clean.csv', index=False)
print(f'\nSaved {len(listings_out):,} listings to data/02-processed/listings_clean.csv')
print(f'Columns ({len(listings_out.columns)}): {list(listings_out.columns)}')
# Out:
# --- Final Listings Dataset ---
# Observations: 7,879
#
# --- Superhost ---
# host_is_superhost
# True     5092
# False    2787
# Name: count, dtype: int64
#
# --- Room Type ---
# room_type
# Entire home/apt    6994
# Private room        844
# Shared room          36
# Hotel room            5
# Name: count, dtype: int64
#
# --- Top 10 Neighborhoods ---
# neighbourhood_cleansed
# Mission Bay      1149
# Pacific Beach     769
# La Jolla          628
# Ocean Beach       483
# North Hills       382
# Midtown           326
# Loma Portal       222
# East Village      208
# Park West         199
# Bay Park          163
# Name: count, dtype: int64
#
# --- Key Numeric Variables ---
#           price  amenity_count  accommodates  bedrooms     beds  bathrooms  host_tenure_years  calculated_host_listings_count  estimated_occupancy_l365d  reviews_per_month  review_scores_rating  review_scores_accuracy  desc_length
# ...

# %% [markdown]
# ### Dataset #2 — San Diego Airbnb Reviews Dataset: `reviews.csv.gz`
# <!-- **Dataset 2: `reviews.csv.gz`** -->
#
# This dataset is also available from Inside Airbnb at the same URL and download page as the listings data, with no access restrictions. The file contains 896,198 individual reviews across 10,962 listings. Below are the relevant columns we have selected:
#
# <!-- | Column | Description | Purpose |
# |---|---|---|
# | `listing_id` | Links the review to a listing | Join key to connect reviews back to listings |
# | `comments` | The actual review text | We run VADER sentiment analysis on this for the guest-side sentiment | -->
#
# | Column | Description | Purpose |
# |---|---|---|
# | `listing_id` | Foreign key linking to the listing's `id` | Join key to connect reviews back to listings |
# | `comments` | The full review text written by the guest | We run sentiment anaylsis on this for the guest-side score of the expectation gap |
# | `id` | Unique review identifier | Row identifier |
# | `date` | Date the review was posted | Could be used for time-based analysis |
#
# **Dataset concerns and shortcomings:**
#
# One major concern with this dataset is the positivity bias in Airbnb reviews. Guests are significantly more likely to leave reviews after positive experiences, while dissatisfied guests often choose not to leave a review at all. As a result, the distribution of sentiment scores is skewed toward the positive end, which may limit the variability needed to accurately measure expectation disconfirmation. This bias makes it more difficult to distinguish between listings that genuinely meet expectations and those that slightly underperform but still receive generally positive feedback.
#
# Another issue is that many reviews are extremely short and therefore contain very little usable sentiment information. For example, over 28,000 reviews in the dataset are under 20 characters long, consisting of comments such as “Great!” or “Nice stay.” While these reviews are technically positive, they provide minimal detail about whether the listing matched, exceeded, or failed to meet expectations.
#
# Additionally, the dataset contains reviews written in multiple languages. Some sentiment analysis tools perform best on English text and may inaccurately score or misinterpret reviews written in other languages. This introduces potential measurement error in the calculation of sentiment-based expectation disconfirmation. Unless multilingual models are used, the results may reflect algorithmic limitations rather than true guest sentiment.
#
# To reduce noise and improve reliability, we mitigate these issues by averaging sentiment scores across five or more reviews per listing. Aggregating reviews at the listing level helps smooth out individual outliers, short comments, and occasional misclassifications. However, despite this mitigation strategy, the dataset remains subject to structural biases in who chooses to leave reviews and how they express their experiences, which should be considered when interpreting results.

# %% [markdown]
# ### San Diego Airbnb Reviews Dataset: Load, Assess, Clean, Save

# %%
# 1. load the dataset 
reviews_raw = pd.read_csv('data/00-raw/reviews.csv.gz', compression='gzip')
print(f'Raw reviews: {reviews_raw.shape[0]:,} rows, {reviews_raw.shape[1]} columns')
print(f'Columns: {list(reviews_raw.columns)}')

# Already tidy: one row per review, one column per variable
reviews = reviews_raw[['listing_id', 'id', 'date', 'comments']].copy()
print(f'Selected columns: {reviews.shape}')

# ---- Missingness ----
print(f'\nMissing comments: {reviews["comments"].isna().sum()} out of {len(reviews):,} ({reviews["comments"].isna().mean():.3%})')
print('=> Only ~0.02% missing — drop since we cannot compute sentiment on empty text.')

# ---- Clean ----
# 1. Drop missing comments
before = len(reviews)
reviews = reviews.dropna(subset=['comments'])
print(f'\nDropped {before - len(reviews)} reviews with no comment text')

# 2. Filter to only reviews for our usable listings
usable_ids = set(listings_clean['id'])
before = len(reviews)
reviews = reviews[reviews['listing_id'].isin(usable_ids)].copy()
print(f'Filtered to usable listings: {len(reviews):,} reviews (dropped {before - len(reviews):,})')
print(f'Unique listings with reviews: {reviews["listing_id"].nunique():,}')

# ---- Flag short / low-signal reviews ----
reviews['comment_length'] = reviews['comments'].str.len()
print(f'\nReview length: mean={reviews["comment_length"].mean():.0f}, median={reviews["comment_length"].median():.0f} chars')
print(f'Very short reviews (<20 chars): {(reviews["comment_length"] < 20).sum():,}')
print(f'Examples: {reviews.loc[reviews["comment_length"] < 20, "comments"].head(5).tolist()}')

# ---- Reviews per listing ----
reviews_per_listing = reviews.groupby('listing_id').size()
print(f'\nReviews per listing: mean={reviews_per_listing.mean():.1f}, median={reviews_per_listing.median():.0f}')

# ---- Save ----
reviews_clean = reviews[['listing_id', 'id', 'date', 'comments']].copy()
reviews_clean.to_csv('data/02-processed/reviews_clean.csv', index=False)
print(f'\nSaved {len(reviews_clean):,} reviews to data/02-processed/reviews_clean.csv')
print(f'Covering {reviews_clean["listing_id"].nunique():,} unique listings')
# Out:
# Raw reviews: 896,198 rows, 6 columns
# Columns: ['listing_id', 'id', 'date', 'reviewer_id', 'reviewer_name', 'comments']
# Selected columns: (896198, 4)
#
# Missing comments: 211 out of 896,198 (0.024%)
# => Only ~0.02% missing — drop since we cannot compute sentiment on empty text.
#
# Dropped 211 reviews with no comment text
# Filtered to usable listings: 786,128 reviews (dropped 109,859)
# Unique listings with reviews: 7,879
#
# Review length: mean=247, median=180 chars
# Very short reviews (<20 chars): 28,163
# Examples: ['Beautiful view!!!', 'Good place to stay.', 'Man ', 'Great location', 'Great location.']
#
# Reviews per listing: mean=99.8, median=52
#
# Saved 786,128 reviews to data/02-processed/reviews_clean.csv
# Covering 7,879 unique listings

# %% [markdown]
# ### Plan to Merge Datasets
# We join the two datasets on `listings.id = reviews.listing_id`. This is a **one-to-many** relationship. Since each listing has many reviews, so the merged dataset has one row per review with that listing's info attached to each row.
#
# - join on listings.id = reviews.listing_id
# - one-to-many join: each listing has many reviews, so the merged
# - dataset has one row per review, with the listing's info attached to each.
#
# We **do not save** this raw merged file. It is 786,128 rows and not yet in the form we need for analysis.
#
# <!-- This structure is what we need to compute the Expectation Gap in the next step:
# 1. For each listing, average VADER sentiment scores across all its `comments` (guest side)
# 2. Compare against the VADER sentiment score of that listing's `description` (host side)
# 3. **Expectation Gap = description sentiment − average review sentiment** -->

# %%
# JOIN: listings.id = reviews.listing_id (one-to-many)
merged = reviews_clean.merge(
    listings_out[['id', 'description', 'host_is_superhost', 'neighbourhood_cleansed', 'price']],
    left_on='listing_id', right_on='id', suffixes=('_review', '_listing')
)
print(f'\n--- Dataset Join ---')
print(f'Merged: {len(merged):,} rows')
print(f'All reviews matched a listing: {len(merged) == len(reviews_clean)}')
print(f'Unique listings in merged data: {merged["listing_id"].nunique():,}')
merged[['listing_id', 'comments', 'host_is_superhost', 'neighbourhood_cleansed', 'price']].head(3)

# We'll compute the Expectation Gap later:
#   - For each listing, average sentiment across all its reviews (guest side)
#   - Compare against the listing's description sentiment (host side)
# Out:
# --- Dataset Join ---
# Merged: 786,128 rows
# All reviews matched a listing: True
# Unique listings in merged data: 7,879
#    listing_id                                           comments  \
# 0           6  Sara is an awesome hostess.  She was very cons...
# 1           6  My stay at “Craftsmen” was wonderful!  Sara wa...
# 2           6  This was my first time using Airbnb and Sara m...
#
#   host_is_superhost neighbourhood_cleansed  price
# 0              True            North Hills  211.0
# 1              True            North Hills  211.0
# 2              True            North Hills  211.0

# %% [markdown]
# ## Results
#
# ### Exploratory Data Analysis
#
# In this section we perform EDA on our cleaned Airbnb listings data with the computed **Expectation Gap** metric. We explore:
#
# 1. **Section 1: Expectation Gap Distribution & Key Variable Relationships** — How is the gap distributed? How does it relate to superhost status, price, room type, neighborhood, and amenities?
# 2. **Section 2: Correlation Analysis & Cross-Validation** — Do our VADER-based gap scores align with Airbnb's guest-rated accuracy scores? What variables are most correlated with the gap?
#
# We load the fully wrangled dataset from `data/02-processed/listings_with_expectation_gap.csv`, which includes the pre-computed VADER sentiment scores and expectation gap (see commented-out computation cells above for methodology).

# %% [markdown]
# #### Section 1: Expectation Gap Distribution & Key Variable Relationships
#
# In this section, we examine:
# - The distribution of our Expectation Gap metric (is it normally distributed? skewed?)
# - How the gap differs across superhost status, room type, and neighborhoods
# - Whether price and amenity count predict the size of the gap
#
# **Reminder:** Expectation Gap = `desc_vader` (host description sentiment) − `mean_review_vader` (average guest review sentiment). Positive = host oversold, negative = host undersold.

# %% [markdown]
# **How the Expectation Gap was computed (already done — DO NOT re-run):**
#
# The cell below ran VADER sentiment analysis on ~786K reviews and ~7,879 listing descriptions. It took ~4 minutes, so the results are pre-saved to `data/02-processed/listings_with_expectation_gap.csv`. The code is commented out so you don't accidentally re-run it — just load the CSV in the next cell.
#
# **TEAMMATES: You do NOT need to touch this cell.** Just run the loading cell after it and start on the plots.

# %%
# import nltk
#%pip install langdetect


# nltk.download('vader_lexicon')

# from nltk.sentiment.vader import SentimentIntensityAnalyzer
# from langdetect import detect, LangDetectException
# from joblib import Parallel, delayed

# sia = SentimentIntensityAnalyzer()

# def get_lang(text):
#     try:
#         return detect(str(text))
#     except LangDetectException:
#         return 'unknown'

# # 0. Filter reviews to only usable listings before anything else
# usable_ids = set(listings_clean['id'])
# reviews_clean = reviews_clean[reviews_clean['listing_id'].isin(usable_ids)].copy()
# print(f"Reviews after filtering to usable listings: {len(reviews_clean):,}")

# # 1. Description VADER (one score per listing)
# listings_clean['desc_vader'] = listings_clean['description'].apply(
#     lambda x: sia.polarity_scores(str(x))['compound']
# )

# # 2. Detect language in parallel
# langs = Parallel(n_jobs=-1)(
#     delayed(get_lang)(text) for text in reviews_clean['comments']
# )
# reviews_clean['lang'] = langs

# # Explore the breakdown
# print(reviews_clean['lang'].value_counts().head(20))
# non_english = reviews_clean[reviews_clean['lang'] != 'en']
# print(f"\nNon-English reviews: {len(non_english):,} ({len(non_english)/len(reviews_clean):.1%})")

# # 3. Filter to English only
# reviews_en = reviews_clean[reviews_clean['lang'] == 'en'].copy()

# # 4. Run VADER on English reviews only
# reviews_en['review_vader'] = reviews_en['comments'].apply(
#     lambda x: sia.polarity_scores(str(x))['compound']
# )

# # 5. Aggregate and merge
# review_sentiment = reviews_en.groupby('listing_id')['review_vader'].mean().reset_index()
# review_sentiment = review_sentiment.rename(columns={'listing_id': 'id', 'review_vader': 'mean_review_vader'})

# listings_clean = listings_clean.merge(review_sentiment, on='id', how='left')
# listings_clean['expectation_gap'] = listings_clean['desc_vader'] - listings_clean['mean_review_vader']

# print(f"\nListings with Expectation Gap computed: {listings_clean['expectation_gap'].notna().sum():,}")
# print(listings_clean['expectation_gap'].describe().round(4))

# %%
# listings_with_expectation_gap = listings_clean.copy()
# listings_with_expectation_gap.to_csv('data/02-processed/listings_with_expectation_gap.csv', index=False)

# %%
# --- Load pre-computed expectation gap data ---
# TEAMMATES: Just run this cell. loads the CSV that is already computed.
listings_with_expectation_gap = pd.read_csv('data/02-processed/listings_with_expectation_gap.csv')
print(f"Loaded {len(listings_with_expectation_gap):,} listings with expectation gap scores")
print(f"\nExpectation Gap summary:")
print(listings_with_expectation_gap['expectation_gap'].describe().round(4))
listings_with_expectation_gap.head()
# Out:
# Loaded 7,879 listings with expectation gap scores
#
# Expectation Gap summary:
# count    7879.0000
# mean       -0.0573
# std         0.3181
# min        -1.7593
# 25%        -0.1076
# 50%         0.0459
# 75%         0.1152
# max         1.0240
# Name: expectation_gap, dtype: float64
#       id                                               name  \
# 0      6    North Park Craftsmen House * Great for Families
# 1  12447                       Cozy Pacific Beach Hideaway!
# 2  29967                   Great home, 10 min walk to Beach
# 3  62274                 charming, colorful, close to beach
# 4  62949  Pacific Beach Cozy Private Hideaway Bikes Incl...
#
#                                          description  \
# 0  This Beautiful Craftsman house has all the mod...
# 1  Your San Diego hideaway awaits!<br /><br />Pri...
# 2  This 2 bedroom, 2 full bathroom home offers al...
# 3  Modern, cozy, artsy, and european in a lush ga...
# 4  Cozy Private Beach Retreat. 420 smoking is ok,...
# ...

# %%
# Load pre-computed data and prep for EDA
listings_gap = listings_with_expectation_gap.copy()
listings_gap['host_is_superhost'] = listings_gap['host_is_superhost'].map(
    {'True': True, 'False': False, True: True, False: False})

print(f"Listings: {len(listings_gap):,}")
print(f"\nExpectation Gap: mean={listings_gap['expectation_gap'].mean():.3f}, "
      f"median={listings_gap['expectation_gap'].median():.3f}")
print(f"Positive (oversold): {(listings_gap['expectation_gap'] > 0).mean():.1%}")
print(f"Negative (undersold): {(listings_gap['expectation_gap'] < 0).mean():.1%}")
# Out:
# Listings: 7,879
#
# Expectation Gap: mean=-0.057, median=0.046
# Positive (oversold): 62.1%
# Negative (undersold): 37.9%

# %%
# Plot 1: Gap distribution + Gap by superhost status
fig, axes = plt.subplots(1, 2, figsize=(13, 5))

axes[0].hist(listings_gap['expectation_gap'].dropna(), bins=50, edgecolor='black', alpha=0.7)
axes[0].axvline(0, color='red', linestyle='--', label='No gap')
axes[0].set(xlabel='Expectation Gap', ylabel='Count', title='Distribution of Expectation Gap')
axes[0].legend()

sh = listings_gap[listings_gap['host_is_superhost'].notna()]
data = [sh[sh['host_is_superhost']==True]['expectation_gap'].dropna(),
        sh[sh['host_is_superhost']==False]['expectation_gap'].dropna()]
axes[1].boxplot(data, labels=['Superhost', 'Non-Superhost'])
axes[1].axhline(0, color='gray', linestyle='--', alpha=0.5)
axes[1].set(ylabel='Expectation Gap', title='Gap by Superhost Status')

plt.tight_layout()
plt.show()
# Out:
# /var/folders/xv/f5c1x2354x794qhmsjdfqlj00000gn/T/ipykernel_96590/692256960.py:12: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   axes[1].boxplot(data, labels=['Superhost', 'Non-Superhost'], patch_artist=True)

# %% [markdown]
# The left histogram is skewed to the left. This indicates that negative expectation gaps are more common than large positive ones. Since a negative gap means review sentiment exceeded description sentiment, this suggests that hosts more often undersell their listings, leading to positive disconfirmation where guests are pleasantly surprised.However, the distribution is tightly centered around zero, meaning most listings have small expectation gaps, implying that host descriptions generally align closely with guest experiences. The long tail of the distribution graph shows that some listings dramatically exceed expectations.
#
#
# The right box plots show the expectation gaps between superhosts and non-superhosts. Both box plots show that both groups have similar median expectation gaps near zero, meaning descriptions generally align with guest experiences regardless of host status. Non-superhosts have more positive expectation gap outliers, indicating that they are somewhat more likely to oversell their listings, resulting in larger negative disconfirmation. In contrast, superhosts appear to have slightly tighter distributions, suggesting more consistent alignment between listing descriptions and guest experiences.

# %%
# Plot 2: Gap by room type + top 10 neighborhoods
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Room type
room_types = listings_gap['room_type'].value_counts()
valid = room_types[room_types > 20].index
room_data = [listings_gap[listings_gap['room_type']==rt]['expectation_gap'].dropna() for rt in valid]
axes[0].boxplot(room_data, labels=valid, patch_artist=True)
axes[0].axhline(0, color='gray', linestyle='--', alpha=0.5)
axes[0].set(ylabel='Expectation Gap', title='Gap by Room Type')
axes[0].tick_params(axis='x', rotation=15)

# Top 10 neighborhoods
top10 = listings_gap['neighbourhood_cleansed'].value_counts().head(10).index
gap_by_hood = (listings_gap[listings_gap['neighbourhood_cleansed'].isin(top10)]
               .groupby('neighbourhood_cleansed')['expectation_gap'].mean().sort_values())
axes[1].barh(gap_by_hood.index, gap_by_hood.values, color='steelblue')
axes[1].axvline(0, color='black', linestyle='-')
axes[1].set(xlabel='Mean Expectation Gap', title='Gap by Neighborhood (Top 10)')

plt.tight_layout()
plt.show()
# Out:
# /var/folders/xv/f5c1x2354x794qhmsjdfqlj00000gn/T/ipykernel_96590/4093306599.py:8: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   axes[0].boxplot(room_data, labels=valid, patch_artist=True)

# %% [markdown]
# **Interpretation:** *(TEAMMATES: Write TEXT HERE — do certain room types or neighborhoods have larger gaps? Any patterns?)*
# There are many extreme values in expectation gap for entire home/apt. The IQR range for the shared room is in the positive expectation gap range, which shows that a majority of guests did not think that their Airbnb met their expectations.
# Something interesting is that all of the neighborhoods except Park West out of the Top 10 Neighborhoods have a negative mean expectation gap. Park West, which is in downtown, are known to be crowded and have lack of parking, so we assume that the more crowded a neighborhood is, the larger the expectation gap gets.

# %%
# Plot 3: Gap vs price (binned) + gap vs amenity count
fig, axes = plt.subplots(1, 2, figsize=(13, 5))

# Price bins
listings_gap['price_bin'] = pd.cut(listings_gap['price'].clip(upper=1000), bins=8)
price_means = listings_gap.groupby('price_bin', observed=True)['expectation_gap'].mean()
axes[0].plot(range(len(price_means)), price_means.values, 'o-', color='coral', linewidth=2)
axes[0].set_xticks(range(len(price_means)))
axes[0].set_xticklabels([f'${int(iv.left)}-{int(iv.right)}' for iv in price_means.index], 
                         rotation=45, ha='right', fontsize=8)
axes[0].axhline(0, color='gray', linestyle='--', alpha=0.5)
axes[0].set(xlabel='Price Range', ylabel='Mean Gap', title='Gap vs Price')

# Amenity count scatter
axes[1].scatter(listings_gap['amenity_count'], listings_gap['expectation_gap'], alpha=0.1, s=10)
z = np.polyfit(listings_gap['amenity_count'], listings_gap['expectation_gap'], 1)
axes[1].plot(np.sort(listings_gap['amenity_count']), np.poly1d(z)(np.sort(listings_gap['amenity_count'])), 
             'r--', linewidth=2)
axes[1].axhline(0, color='gray', linestyle='--', alpha=0.5)
axes[1].set(xlabel='Amenity Count', ylabel='Expectation Gap', title='Gap vs Amenities')

plt.tight_layout()
plt.show()

# %% [markdown]
# The mean expectation gap is negative across all price ranges, indicating that guests generally perceive their experience slightly more positively than the listing description suggests. We see that in between $381-629 range, the mean expectation gap increases, as well as the highest range at $876-1000. Overall, price does not appear to strongly determine expectation gaps, although higher-end listings show slightly greater positive disconfirmation.
#
# The scatter plot suggests a very weak negative relationship between amenity count and expectation gap, as indicated by the slightly downward-sloping trend line. We can see a drop in expectation gap in between 40~60 amenity count. There is a spike in positive expectation gap right before 20 amenities, which shows that having too few amenities listed can increase the expectation gap. The relationship between more amenities and expectation gap appears weak, as most observations cluster near zero across the full range of amenity counts. This indicates that amenity count alone does not strongly explain expectation disconfirmation.

# %% [markdown]
# #### Section 2: Correlation Analysis & Metric Validation
#
# We validate our Expectation Gap by checking if it correlates with Airbnb's guest-rated `review_scores_accuracy`. If our NLP-based gap captures real mismatch, we expect a negative correlation: hosts who oversell (positive gap) should get lower accuracy ratings from guests.

# %%
# Plot 4: Predictor correlation matrix + cross-validation (gap vs accuracy score)
fig, axes = plt.subplots(1, 2, figsize=(15, 6))

# --- Correlation heatmap (predictors only) ---
# desc_vader is excluded: it is mechanically half of the gap formula (gap = desc_vader - mean_review_vader),
# so its r≈0.96 with expectation_gap is not informative about real pre-booking predictors.
predictor_cols = [
    'expectation_gap',
    'desc_length',                      # description language: character length
    'amenity_count',                    # listing feature: number of amenities
    'price',                            # listing feature: nightly price
    'host_tenure_years',               # host experience: years on Airbnb
    'calculated_host_listings_count',  # host experience: number of listings managed
    'reviews_per_month',               # booking frequency proxy
    'estimated_occupancy_l365d',       # booking frequency: est. nights booked in last year
    'review_scores_accuracy',          # validation: guest-rated accuracy sub-score
]

labels = [
    'Expectation Gap',
    'Desc. Length',
    'Amenity Count',
    'Price',
    'Host Tenure (yrs)',
    'Host Listing Count',
    'Reviews/Month',
    'Est. Occupancy',
    'Accuracy Score',
]

corr = listings_gap[predictor_cols].corr()
corr.index = labels
corr.columns = labels

sns.heatmap(corr, annot=True, fmt='.2f', cmap='RdBu_r', center=0, ax=axes[0],
            square=True, linewidths=0.5, cbar_kws={'shrink': 0.8},
            annot_kws={'size': 8})
axes[0].set_title('Predictor Correlation Matrix\n(mechanically-related VADER scores excluded)', fontsize=10)
axes[0].tick_params(axis='both', labelsize=8)

# --- Cross-validation: gap vs Airbnb's accuracy rating ---
plot_data = listings_gap[['expectation_gap', 'review_scores_accuracy']].dropna()
r = plot_data.corr().iloc[0, 1]
axes[1].scatter(plot_data['expectation_gap'], plot_data['review_scores_accuracy'],
                alpha=0.1, s=10, color='steelblue')
z = np.polyfit(plot_data['expectation_gap'], plot_data['review_scores_accuracy'], 1)
x_line = np.linspace(plot_data['expectation_gap'].min(), plot_data['expectation_gap'].max(), 100)
axes[1].plot(x_line, np.poly1d(z)(x_line), 'r--', linewidth=2, label=f'Trend (r={r:.3f})')
axes[1].set(xlabel='Expectation Gap', ylabel='Review Accuracy Score (guest-rated)',
            title='Cross-Validation: Gap vs Airbnb Accuracy Score')
axes[1].legend()

plt.tight_layout()
plt.savefig('results/plot4_correlation_validation.png', dpi=150, bbox_inches='tight')
plt.show()

# Print sorted correlations with gap for quick reference
print("Correlations with Expectation Gap (predictors only):")
print(corr['Expectation Gap'].drop('Expectation Gap').sort_values(key=abs, ascending=False).round(3).to_string())

# %% [markdown]
# The correlation matrix now shows only true pre-booking predictors, excluding `desc_vader` and `mean_review_vader` which are mechanically part of the gap formula and would inflate apparent correlation.
#
# Key findings from the predictor correlation matrix:
# - **Description length** (r ≈ 0.36) is the strongest real predictor of expectation gap — longer descriptions are associated with a more positive gap (host overselling relative to guest experience). This supports the idea that verbose hosts make harder-to-meet promises.
# - **Amenity count** (r ≈ 0.01) and **price** (r ≈ 0.02) show near-zero correlation with the gap — contrary to our hypothesis, neither strongly predicts whether a host oversells.
# - **Host tenure** and **host listing count** show weak negative correlations (r ≈ −0.05 to −0.09), suggesting more experienced hosts have slightly smaller gaps, but the effect is modest.
# - **Estimated occupancy** and **reviews per month** have very weak correlations with the gap, making the relationship between gap size and booking demand unclear from correlation alone.
#
# The cross-validation scatter plot confirms a weak but expected negative relationship (r ≈ −0.16) between our computed Expectation Gap and Airbnb's guest-rated accuracy sub-score: listings where the host oversold (positive gap) tend to receive slightly lower accuracy ratings. The ceiling effect is visible — many listings cluster near the maximum accuracy score of 5.0, compressing the range and attenuating the correlation.

# %% [markdown]
# ## Ethics

# %% [markdown]
# ### A. Data Collection
#  - [X] **A.1 Informed consent**: If there are human subjects, have they given informed consent, where subjects affirmatively opt-in and have a clear understanding of the data uses to which they consent?
#
# > While the information we are using is public and was put online by Airbnb users, they do not have a clear understanding that their data will be used in our project.
#
#  - [ ] **A.2 Collection bias**: Have we considered sources of bias that could be introduced during data collection and survey design and taken steps to mitigate those?
#  - [X] **A.3 Limit PII exposure**: Have we considered ways to minimize exposure of personally identifiable information (PII) for example through anonymization or not collecting information that isn't relevant for analysis?
#
# > The information we are collecting might reveal identifiable details about a listing so there might be a problem with listings being poorly anonymized, but the risk is not high.
#
#
#  - [ ] **A.4 Downstream bias mitigation**: Have we considered ways to enable testing downstream results for biased outcomes (e.g., collecting data on protected group status like race or gender)?
#
# ### B. Data Storage
#  - [X] **B.1 Data security**: Do we have a plan to protect and secure data (e.g., encryption at rest and in transit, access controls on internal users and third parties, access logs, and up-to-date software)?
#
#  > All the information is already public for us to use. There are no identifiable details about the reviewers in the dataset that would be considered a breach.
#
#  - [ ] **B.2 Right to be forgotten**: Do we have a mechanism through which an individual can request their personal information be removed?
#  - [ ] **B.3 Data retention plan**: Is there a schedule or plan to delete the data after it is no longer needed?
#
# ### C. Analysis
#  - [ ] **C.1 Missing perspectives**: Have we sought to address blindspots in the analysis through engagement with relevant stakeholders (e.g., checking assumptions and discussing implications with affected communities and subject matter experts)?
#  - [X] **C.2 Dataset bias**: Have we examined the data for possible sources of bias and taken steps to mitigate or address these biases (e.g., stereotype perpetuation, confirmation bias, imbalanced classes, or omitted confounding variables)?
#
# > A large majority of airbnb reviews are positive, especially if the listing is in a good area like San Diego, there might be a slight bias.
#
#  - [X] **C.3 Honest representation**: Are our visualizations, summary statistics, and reports designed to honestly represent the underlying data?
#  - [X] **C.4 Privacy in analysis**: Have we ensured that data with PII are not used or displayed unless necessary for the analysis?
#  - [X] **C.5 Auditability**: Is the process of generating the analysis well documented and reproducible if we discover issues in the future?
#
# ### D. Modeling
#  - [X] **D.1 Proxy discrimination**: Have we ensured that the model does not rely on variables or proxies for variables that are unfairly discriminatory?
#
# > No personally identifiable information about reviewers will be accounted for.
#
#
#  - [ ] **D.2 Fairness across groups**: Have we tested model results for fairness with respect to different affected groups (e.g., tested for disparate error rates)?
#  - [ ] **D.3 Metric selection**: Have we considered the effects of optimizing for our defined metrics and considered additional metrics?
#  - [ ] **D.4 Explainability**: Can we explain in understandable terms a decision the model made in cases where a justification is needed?
#  - [X] **D.5 Communicate limitations**: Have we communicated the shortcomings, limitations, and biases of the model to relevant stakeholders in ways that can be generally understood?
#
#
#
# ### E. Deployment
#  - [ ] **E.1 Monitoring and evaluation**: Do we have a clear plan to monitor the model and its impacts after it is deployed (e.g., performance monitoring, regular audit of sample predictions, human review of high-stakes decisions, reviewing downstream impacts of errors or low-confidence decisions, testing for concept drift)?
#  - [ ] **E.2 Redress**: Have we discussed with our organization a plan for response if users are harmed by the results (e.g., how does the data science team evaluate these cases and update analysis and models to prevent future harm)?
#  - [ ] **E.3 Roll back**: Is there a way to turn off or roll back the model in production if necessary?
#  - [ ] **E.4 Unintended use**: Have we taken steps to identify and prevent unintended uses and abuse of the model and do we have a plan to monitor these once the model is deployed?

# %% [markdown]
# ## Team Expectations

# %% [markdown]
# * *We are going to mainly communicate through iMessage and Discord.*
# * *We will meet at least once a week for one hour.*
# * *Communicate before deciding on a big decision*
# * *Text one or all of us if you are struggling, reach out early, and be honest.*
# * *Make sure everything is done on time*
# * *Practice good github repository practices (message commits, and document everything on READ.ME)*

# %% [markdown]
# ## Project Timeline Proposal

# %% [markdown]
# | Meeting Date  | Meeting Time| Completed Before Meeting  | Discuss at Meeting |
# |---|---|---|---|
# | 1/18  |  10 AM | Read & Think about COGS 108 expectations; brainstorm topics/questions  | Determine best form of communication; Discuss and decide on final project topic; discuss hypothesis; begin background research |
# | 1/21  |  4 PM |  Do background research on topic | Discuss ideal dataset(s) and ethics; draft project proposal |
# | 1/28  | 4 PM  | Edit, finalize, and submit proposal; Search for datasets  | Completed Project Review   |
# | 2/3  | 5 PM  | Brainstorming Research Question | Finalize Research Question and look over Project Proposal   |
# | 2/4  | 4 PM  | Prior research and filled in parts of Project Proposal | Discuss/edit Analysis; Complete project check-in |
# | 2/11  | 4 PM  | Find multiple data resources | Start working on Checkpoint #1 |
# | 2/18  | 4 PM | Review TA comments and Work on finishing Checkpoint #1 | Discuss and turn in Checkpoint #1: Data |
# | 2/25  | 4 PM  | Start EDA on our dataset | Keep working on the EDA |
# | 3/4  | 4 PM  | Turn in Checkpoint #2: EDA | Start working on the Analysis part together |
# | 3/11  | 4 PM  | Complete analysis; Draft results/conclusion/discussion | Discuss/edit full project |
# | 3/18  | Before 11:59 PM  | NA | Turn in Final Project & Group Project Surveys |
